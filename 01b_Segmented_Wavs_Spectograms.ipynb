# %% [markdown]
# <a href="https://colab.research.google.com/github/CSCCNY/final-project-recomposeclassics/blob/main/Segmented_Wavs_Spectograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Recompose Classics : **Data Preprocessing**
# Hannah Do
#
# May 4th, 2021
#
#
#
# ---
#
#
# ##### **Summary**
#
# 1. Conversion of **midi** to **wav** files :
#
#  *fluidsynth*
#
#
# 2. Segmenting each **wav** files into smaller  pieces (15 sec)  :
#
#  *pydub - AudioSegment*
#
#
# 3. Conversion of **wav** files to **spectograms** :
#
#   *librosa*
#
#
# ---

# %% [markdown]
# **Mount from Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Get folder with Chopin classics only**

# %%
import os
import matplotlib.pyplot as plt

import librosa
import librosa.display

import IPython.display as ipd

import numpy as np
import random

# %%
audio_fpath = "/content/gdrive/My Drive/Classics_DNN/"
audio_clips = os.listdir(audio_fpath+'chopin_midi/')
print("No. of .midi files in audio folder = ",len(audio_clips))
# Out:
# No. of .midi files in audio folder =  48

# %% [markdown]
# **Imports to convert midi files into wav files - fluidsynth**

# %%
# !sudo apt install fluidsynth
# !cp /usr/share/sounds/sf2/FluidR3_GM.sf2 ./font.sf2

# !cp /content/gdrive/My\ Drive/Classics_DNN/unzipped_classics/chopin_midi/*.mid /content/mids/
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fluid-soundfont-gm libfluidsynth1 libqt5x11extras5 qsynth
# Suggested packages:
#   fluid-soundfont-gs timidity jackd
# The following NEW packages will be installed:
#   fluid-soundfont-gm fluidsynth libfluidsynth1 libqt5x11extras5 qsynth
# 0 upgraded, 5 newly installed, 0 to remove and 31 not upgraded.
# Need to get 120 MB of archives.
# After this operation, 150 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fluid-soundfont-gm all 3.1-5.1 [119 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth1 amd64 1.1.9-1 [137 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fluidsynth amd64 1.1.9-1 [20.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5x11extras5 amd64 5.9.5-0ubuntu1 [8,596 B]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qsynth amd64 0.5.0-2 [191 kB]
# Fetched 120 MB in 5s (23.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 5.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fluid-soundfont-gm.
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../fluid-soundfont-gm_3.1-5.1_all.deb ...
# Unpacking fluid-soundfont-gm (3.1-5.1) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Selecting previously unselected package fluidsynth.
# Preparing to unpack .../fluidsynth_1.1.9-1_amd64.deb ...
# Unpacking fluidsynth (1.1.9-1) ...
# Selecting previously unselected package libqt5x11extras5:amd64.
# Preparing to unpack .../libqt5x11extras5_5.9.5-0ubuntu1_amd64.deb ...
# Unpacking libqt5x11extras5:amd64 (5.9.5-0ubuntu1) ...
# Selecting previously unselected package qsynth.
# Preparing to unpack .../qsynth_0.5.0-2_amd64.deb ...
# Unpacking qsynth (0.5.0-2) ...
# Setting up libqt5x11extras5:amd64 (5.9.5-0ubuntu1) ...
# Setting up fluid-soundfont-gm (3.1-5.1) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up fluidsynth (1.1.9-1) ...
# Setting up qsynth (0.5.0-2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# cp: cannot stat '/content/gdrive/My Drive/Classics_DNN/unzipped_classics/chopin/*.mid': No such file or directory

# %% [markdown]
# **Change of directory to 'content' during 'midi to wav' conversion and back to google drive folder to avoid shell script error**

# %%
i=0
for i in range(len(audio_clips)):
  ! fluidsynth -ni font.sf2 {'/content/mids/'+audio_clips[i]} -F {'/content/wavs/'+os.path.splitext(audio_clips[i])[0]+'.wav'} -r 44100
  print(os.path.splitext(audio_clips[i])[0]+'.wav file downloaded \n')
  i += 1

# %%
# !cp /content/wavs/*wav /content/gdrive/My\ Drive/Classics_DNN/unzipped_classics/chopin_wav

# %% [markdown]
# **Open through librosa as numpy array**

# %%
audio_fpath = '/content/gdrive/My Drive/Classics_DNN/unzipped_classics/chopin_wav/'
audio_clips = os.listdir(audio_fpath)

x, sr = librosa.load(audio_fpath+audio_clips[0], sr=44100)

print(type(x), type(sr))
print(x.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (4918720,) 44100

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %% [markdown]
# **Segment the wav files into 15 second wav files with 5 seconds of overlap**

# %%
! pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
from pydub import AudioSegment
import math
# Out:
# C:\Users\SAMSUNG\anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
class SplitWavFiles():
    def __init__(self, folder, folder2, filename):
        self.folder = folder
        self.folder2 = folder2
        self.filename = filename
        self.filepath = folder + filename
        
        self.audio = AudioSegment.from_wav(self.filepath)

    def get_duration(self):
        return self.audio.duration_seconds
    
    def single_split(self, from_min, to_min, split_filename):
        t1 = from_min * 1000
        t2 = to_min * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export(self.folder2 + split_filename, format="wav")
        
    def multiple_split(self, sec_per_split):
        total_mins = math.ceil(self.get_duration())
        # overlap of every 5 seconds
        for i in range(0, total_mins, 5):
            split_fn = str(i) + '_' +  self.filename 
            self.single_split(i, i+sec_per_split, split_fn)
            print(str(i) + ' Done')
            if i == total_mins - sec_per_split:
                print('')

# %%
orig_filepath = '/Users/SAMSUNG/Downloads/dnn_data/chopin_full_wavs/'
segmented_filepath = '/Users/SAMSUNG/Downloads/dnn_data/chopin_segmented_wavs/'
audio_clips = os.listdir(orig_filepath)

# %%
print("No. of files in Original Wavs folder = ",len(audio_clips))
# Out:
# No. of files in Original Wavs folder =  48

# %%
for i in audio_clips:

  split_wav = SplitWavFiles(orig_filepath, segmented_filepath, i)
  # split wav files to 15 sec each
  split_wav.multiple_split(sec_per_split=15)

  print('\n' + i +' file splitted into 15 sec files \n\n')

# %%
segmented_filepath = '/content/gdrive/My Drive/Classics_DNN/chopin_segmented_wavs/'
audio_clips = os.listdir(segmented_filepath)

# %%
print("No. of files in Segmented Wavs folder = ",len(audio_clips))
# Out:
# No. of files in Segmented Wavs folder =  1575

# %% [markdown]
# **Segment the wav files into halves for input and output data**

# %%
class SplitWavFiles2():
    def __init__(self, folder, folder2, filename):
        self.folder = folder
        self.folder2 = folder2
        self.filename = filename
        self.filepath = folder + filename
        
        self.audio = AudioSegment.from_wav(self.filepath)

    def get_duration2(self):
        return self.audio.duration_seconds
    
    def single_split2(self, from_min, to_min, split_filename):
        t1 = from_min * 1000
        t2 = to_min * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export(self.folder2 + split_filename, format="wav")
        
    def multiple_split2(self, sec_per_split):
        total_mins = math.ceil(self.get_duration2())
        
        split_fn = 'in_' +  self.filename 
        self.single_split2(0, 7.5, split_fn)
        print(split_fn + ' Done')
        if i == total_mins - sec_per_split:
            print('left over wav file')

        split_fn = 'out_' +  self.filename 
        self.single_split2(7.5, 15, split_fn)
        print(split_fn + ' Done')
        if i == total_mins - sec_per_split:
            print('left over wav file')

# %%
orig_filepath = '/Users/SAMSUNG/Downloads/dnn_data/chopin_segmented_wavs/'
segmented_filepath = '/Users/SAMSUNG/Downloads/dnn_data/chopin_inout/'
audio_clips = os.listdir(orig_filepath)

# %%
for i in audio_clips:

  split_wav = SplitWavFiles2(orig_filepath, segmented_filepath, i)
  # split wav files to 15 sec each
  split_wav.multiple_split2(sec_per_split=7.5)

  print('\n' + i +' file splitted into 7.5 sec files \n\n')
# Out:
# in_0_chpn-p1.wav Done
# out_0_chpn-p1.wav Done
#
# 0_chpn-p1.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p10.wav Done
# out_0_chpn-p10.wav Done
#
# 0_chpn-p10.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p11.wav Done
# out_0_chpn-p11.wav Done
#
# 0_chpn-p11.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p12.wav Done
# out_0_chpn-p12.wav Done
#
# 0_chpn-p12.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p13.wav Done
# out_0_chpn-p13.wav Done
#
# 0_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p14.wav Done
# out_0_chpn-p14.wav Done
#
# 0_chpn-p14.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p15.wav Done
# out_0_chpn-p15.wav Done
#
# 0_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p16.wav Done
# out_0_chpn-p16.wav Done
#
# 0_chpn-p16.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p17.wav Done
# out_0_chpn-p17.wav Done
#
# 0_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p18.wav Done
# out_0_chpn-p18.wav Done
#
# 0_chpn-p18.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p19.wav Done
# out_0_chpn-p19.wav Done
#
# 0_chpn-p19.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p2.wav Done
# out_0_chpn-p2.wav Done
#
# 0_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p20.wav Done
# out_0_chpn-p20.wav Done
#
# 0_chpn-p20.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p21.wav Done
# out_0_chpn-p21.wav Done
#
# 0_chpn-p21.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p22.wav Done
# out_0_chpn-p22.wav Done
#
# 0_chpn-p22.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p23.wav Done
# out_0_chpn-p23.wav Done
#
# 0_chpn-p23.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p24.wav Done
# out_0_chpn-p24.wav Done
#
# 0_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p3.wav Done
# out_0_chpn-p3.wav Done
#
# 0_chpn-p3.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p4.wav Done
# out_0_chpn-p4.wav Done
#
# 0_chpn-p4.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p5.wav Done
# out_0_chpn-p5.wav Done
#
# 0_chpn-p5.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p6.wav Done
# out_0_chpn-p6.wav Done
#
# 0_chpn-p6.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p7.wav Done
# out_0_chpn-p7.wav Done
#
# 0_chpn-p7.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p8.wav Done
# out_0_chpn-p8.wav Done
#
# 0_chpn-p8.wav file splitted into 7.5 sec files
#
#
# in_0_chpn-p9.wav Done
# out_0_chpn-p9.wav Done
#
# 0_chpn-p9.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op10_e01.wav Done
# out_0_chpn_op10_e01.wav Done
#
# 0_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op10_e05.wav Done
# out_0_chpn_op10_e05.wav Done
#
# 0_chpn_op10_e05.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op10_e12.wav Done
# out_0_chpn_op10_e12.wav Done
#
# 0_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op23.wav Done
# out_0_chpn_op23.wav Done
#
# 0_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op25_e1.wav Done
# out_0_chpn_op25_e1.wav Done
#
# 0_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op25_e11.wav Done
# out_0_chpn_op25_e11.wav Done
#
# 0_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op25_e12.wav Done
# out_0_chpn_op25_e12.wav Done
#
# 0_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op25_e2.wav Done
# out_0_chpn_op25_e2.wav Done
#
# 0_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op25_e3.wav Done
# out_0_chpn_op25_e3.wav Done
#
# 0_chpn_op25_e3.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op25_e4.wav Done
# out_0_chpn_op25_e4.wav Done
#
# 0_chpn_op25_e4.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op27_1.wav Done
# out_0_chpn_op27_1.wav Done
#
# 0_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op27_2.wav Done
# out_0_chpn_op27_2.wav Done
#
# 0_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op33_2.wav Done
# out_0_chpn_op33_2.wav Done
#
# 0_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op33_4.wav Done
# out_0_chpn_op33_4.wav Done
#
# 0_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op35_1.wav Done
# out_0_chpn_op35_1.wav Done
#
# 0_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op35_2.wav Done
# out_0_chpn_op35_2.wav Done
#
# 0_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op35_3.wav Done
# out_0_chpn_op35_3.wav Done
#
# 0_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op35_4.wav Done
# out_0_chpn_op35_4.wav Done
#
# 0_chpn_op35_4.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op53.wav Done
# out_0_chpn_op53.wav Done
#
# 0_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op66.wav Done
# out_0_chpn_op66.wav Done
#
# 0_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op7_1.wav Done
# out_0_chpn_op7_1.wav Done
#
# 0_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_0_chpn_op7_2.wav Done
# out_0_chpn_op7_2.wav Done
#
# 0_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_0_chp_op18.wav Done
# out_0_chp_op18.wav Done
#
# 0_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_0_chp_op31.wav Done
# out_0_chp_op31.wav Done
#
# 0_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_100_chpn-p13.wav Done
# out_100_chpn-p13.wav Done
#
# 100_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_100_chpn-p15.wav Done
# out_100_chpn-p15.wav Done
#
# 100_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_100_chpn-p17.wav Done
# out_100_chpn-p17.wav Done
#
# 100_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_100_chpn-p2.wav Done
# out_100_chpn-p2.wav Done
#
# 100_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_100_chpn-p24.wav Done
# out_100_chpn-p24.wav Done
#
# 100_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op10_e12.wav Done
# out_100_chpn_op10_e12.wav Done
#
# 100_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op23.wav Done
# out_100_chpn_op23.wav Done
#
# 100_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op25_e1.wav Done
# out_100_chpn_op25_e1.wav Done
#
# 100_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op25_e11.wav Done
# out_100_chpn_op25_e11.wav Done
#
# 100_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op25_e12.wav Done
# out_100_chpn_op25_e12.wav Done
#
# 100_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op25_e2.wav Done
# out_100_chpn_op25_e2.wav Done
#
# 100_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op27_1.wav Done
# out_100_chpn_op27_1.wav Done
#
# 100_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op27_2.wav Done
# out_100_chpn_op27_2.wav Done
#
# 100_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op33_2.wav Done
# out_100_chpn_op33_2.wav Done
#
# 100_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op33_4.wav Done
# out_100_chpn_op33_4.wav Done
#
# 100_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op35_1.wav Done
# out_100_chpn_op35_1.wav Done
#
# 100_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op35_2.wav Done
# out_100_chpn_op35_2.wav Done
#
# 100_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op35_3.wav Done
# out_100_chpn_op35_3.wav Done
#
# 100_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op53.wav Done
# out_100_chpn_op53.wav Done
#
# 100_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op66.wav Done
# out_100_chpn_op66.wav Done
#
# 100_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op7_1.wav Done
# out_100_chpn_op7_1.wav Done
#
# 100_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_100_chpn_op7_2.wav Done
# out_100_chpn_op7_2.wav Done
#
# 100_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_100_chp_op18.wav Done
# out_100_chp_op18.wav Done
#
# 100_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_100_chp_op31.wav Done
# out_100_chp_op31.wav Done
#
# 100_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_105_chpn-p13.wav Done
# out_105_chpn-p13.wav Done
#
# 105_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_105_chpn-p15.wav Done
# out_105_chpn-p15.wav Done
#
# 105_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_105_chpn-p17.wav Done
# out_105_chpn-p17.wav Done
#
# 105_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_105_chpn-p2.wav Done
# out_105_chpn-p2.wav Done
#
# 105_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_105_chpn-p24.wav Done
# out_105_chpn-p24.wav Done
#
# 105_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op10_e12.wav Done
# out_105_chpn_op10_e12.wav Done
#
# 105_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op23.wav Done
# out_105_chpn_op23.wav Done
#
# 105_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op25_e1.wav Done
# out_105_chpn_op25_e1.wav Done
#
# 105_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op25_e11.wav Done
# out_105_chpn_op25_e11.wav Done
#
# 105_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op25_e12.wav Done
# out_105_chpn_op25_e12.wav Done
#
# 105_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op25_e2.wav Done
# out_105_chpn_op25_e2.wav Done
#
# 105_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op27_1.wav Done
# out_105_chpn_op27_1.wav Done
#
# 105_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op27_2.wav Done
# out_105_chpn_op27_2.wav Done
#
# 105_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op33_2.wav Done
# out_105_chpn_op33_2.wav Done
#
# 105_chpn_op33_2.wav file splitted into 7.5 sec files
# in_105_chpn_op33_4.wav Done
# out_105_chpn_op33_4.wav Done
#
# 105_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op35_1.wav Done
# out_105_chpn_op35_1.wav Done
#
# 105_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op35_2.wav Done
# out_105_chpn_op35_2.wav Done
#
# 105_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op35_3.wav Done
# out_105_chpn_op35_3.wav Done
#
# 105_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op53.wav Done
# out_105_chpn_op53.wav Done
#
# 105_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op66.wav Done
# out_105_chpn_op66.wav Done
#
# 105_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op7_1.wav Done
# out_105_chpn_op7_1.wav Done
#
# 105_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_105_chpn_op7_2.wav Done
# out_105_chpn_op7_2.wav Done
#
# 105_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_105_chp_op18.wav Done
# out_105_chp_op18.wav Done
#
# 105_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_105_chp_op31.wav Done
# out_105_chp_op31.wav Done
#
# 105_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p1.wav Done
# out_10_chpn-p1.wav Done
#
# 10_chpn-p1.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p11.wav Done
# out_10_chpn-p11.wav Done
#
# 10_chpn-p11.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p12.wav Done
# out_10_chpn-p12.wav Done
#
# 10_chpn-p12.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p13.wav Done
# out_10_chpn-p13.wav Done
#
# 10_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p14.wav Done
# out_10_chpn-p14.wav Done
#
# 10_chpn-p14.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p15.wav Done
# out_10_chpn-p15.wav Done
#
# 10_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p16.wav Done
# out_10_chpn-p16.wav Done
#
# 10_chpn-p16.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p17.wav Done
# out_10_chpn-p17.wav Done
#
# 10_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p18.wav Done
# out_10_chpn-p18.wav Done
#
# 10_chpn-p18.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p19.wav Done
# out_10_chpn-p19.wav Done
#
# 10_chpn-p19.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p2.wav Done
# out_10_chpn-p2.wav Done
#
# 10_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p20.wav Done
# out_10_chpn-p20.wav Done
#
# 10_chpn-p20.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p21.wav Done
# out_10_chpn-p21.wav Done
#
# 10_chpn-p21.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p22.wav Done
# out_10_chpn-p22.wav Done
#
# 10_chpn-p22.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p23.wav Done
# out_10_chpn-p23.wav Done
#
# 10_chpn-p23.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p24.wav Done
# out_10_chpn-p24.wav Done
#
# 10_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p3.wav Done
# out_10_chpn-p3.wav Done
#
# 10_chpn-p3.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p4.wav Done
# out_10_chpn-p4.wav Done
#
# 10_chpn-p4.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p5.wav Done
# out_10_chpn-p5.wav Done
#
# 10_chpn-p5.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p6.wav Done
# out_10_chpn-p6.wav Done
#
# 10_chpn-p6.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p7.wav Done
# out_10_chpn-p7.wav Done
#
# 10_chpn-p7.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p8.wav Done
# out_10_chpn-p8.wav Done
#
# 10_chpn-p8.wav file splitted into 7.5 sec files
#
#
# in_10_chpn-p9.wav Done
# out_10_chpn-p9.wav Done
#
# 10_chpn-p9.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op10_e01.wav Done
# out_10_chpn_op10_e01.wav Done
#
# 10_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op10_e05.wav Done
# out_10_chpn_op10_e05.wav Done
#
# 10_chpn_op10_e05.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op10_e12.wav Done
# out_10_chpn_op10_e12.wav Done
#
# 10_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op23.wav Done
# out_10_chpn_op23.wav Done
#
# 10_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op25_e1.wav Done
# out_10_chpn_op25_e1.wav Done
#
# 10_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op25_e11.wav Done
# out_10_chpn_op25_e11.wav Done
#
# 10_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op25_e12.wav Done
# out_10_chpn_op25_e12.wav Done
#
# 10_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op25_e2.wav Done
# out_10_chpn_op25_e2.wav Done
#
# 10_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op25_e3.wav Done
# out_10_chpn_op25_e3.wav Done
#
# 10_chpn_op25_e3.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op25_e4.wav Done
# out_10_chpn_op25_e4.wav Done
#
# 10_chpn_op25_e4.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op27_1.wav Done
# out_10_chpn_op27_1.wav Done
#
# 10_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op27_2.wav Done
# out_10_chpn_op27_2.wav Done
#
# 10_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op33_2.wav Done
# out_10_chpn_op33_2.wav Done
#
# 10_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op33_4.wav Done
# out_10_chpn_op33_4.wav Done
#
# 10_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op35_1.wav Done
# out_10_chpn_op35_1.wav Done
#
# 10_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op35_2.wav Done
# out_10_chpn_op35_2.wav Done
#
# 10_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op35_3.wav Done
# out_10_chpn_op35_3.wav Done
#
# 10_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op35_4.wav Done
# out_10_chpn_op35_4.wav Done
#
# 10_chpn_op35_4.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op53.wav Done
# out_10_chpn_op53.wav Done
#
# 10_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op66.wav Done
# out_10_chpn_op66.wav Done
#
# 10_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op7_1.wav Done
# out_10_chpn_op7_1.wav Done
#
# 10_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_10_chpn_op7_2.wav Done
# out_10_chpn_op7_2.wav Done
#
# 10_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_10_chp_op18.wav Done
# out_10_chp_op18.wav Done
#
# 10_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_10_chp_op31.wav Done
# out_10_chp_op31.wav Done
#
# 10_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_110_chpn-p13.wav Done
# out_110_chpn-p13.wav Done
#
# 110_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_110_chpn-p15.wav Done
# out_110_chpn-p15.wav Done
#
# 110_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_110_chpn-p17.wav Done
# out_110_chpn-p17.wav Done
#
# 110_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_110_chpn-p24.wav Done
# out_110_chpn-p24.wav Done
#
# 110_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op10_e12.wav Done
# out_110_chpn_op10_e12.wav Done
#
# 110_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op23.wav Done
# out_110_chpn_op23.wav Done
#
# 110_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op25_e1.wav Done
# out_110_chpn_op25_e1.wav Done
#
# 110_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op25_e11.wav Done
# out_110_chpn_op25_e11.wav Done
#
# 110_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op25_e12.wav Done
# out_110_chpn_op25_e12.wav Done
#
# 110_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op27_1.wav Done
# out_110_chpn_op27_1.wav Done
#
# 110_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op27_2.wav Done
# out_110_chpn_op27_2.wav Done
#
# 110_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op33_2.wav Done
# out_110_chpn_op33_2.wav Done
#
# 110_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op33_4.wav Done
# out_110_chpn_op33_4.wav Done
#
# 110_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op35_1.wav Done
# out_110_chpn_op35_1.wav Done
#
# 110_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op35_2.wav Done
# out_110_chpn_op35_2.wav Done
#
# 110_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op35_3.wav Done
# out_110_chpn_op35_3.wav Done
#
# 110_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op53.wav Done
# out_110_chpn_op53.wav Done
#
# 110_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op66.wav Done
# out_110_chpn_op66.wav Done
#
# 110_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op7_1.wav Done
# out_110_chpn_op7_1.wav Done
#
# 110_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_110_chpn_op7_2.wav Done
# out_110_chpn_op7_2.wav Done
#
# 110_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_110_chp_op18.wav Done
# out_110_chp_op18.wav Done
#
# 110_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_110_chp_op31.wav Done
# out_110_chp_op31.wav Done
#
# 110_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_115_chpn-p13.wav Done
# out_115_chpn-p13.wav Done
#
# 115_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_115_chpn-p15.wav Done
# out_115_chpn-p15.wav Done
#
# 115_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_115_chpn-p17.wav Done
# out_115_chpn-p17.wav Done
#
# 115_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op10_e12.wav Done
# out_115_chpn_op10_e12.wav Done
#
# 115_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op23.wav Done
# out_115_chpn_op23.wav Done
#
# 115_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op25_e11.wav Done
# out_115_chpn_op25_e11.wav Done
#
# 115_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op25_e12.wav Done
# out_115_chpn_op25_e12.wav Done
#
# 115_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op27_1.wav Done
# out_115_chpn_op27_1.wav Done
#
# 115_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op27_2.wav Done
# out_115_chpn_op27_2.wav Done
#
# 115_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op33_2.wav Done
# out_115_chpn_op33_2.wav Done
#
# 115_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op33_4.wav Done
# out_115_chpn_op33_4.wav Done
#
# 115_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op35_1.wav Done
# out_115_chpn_op35_1.wav Done
#
# 115_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op35_2.wav Done
# out_115_chpn_op35_2.wav Done
#
# 115_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op35_3.wav Done
# out_115_chpn_op35_3.wav Done
#
# 115_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op53.wav Done
# out_115_chpn_op53.wav Done
#
# 115_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op66.wav Done
# out_115_chpn_op66.wav Done
#
# 115_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op7_1.wav Done
# out_115_chpn_op7_1.wav Done
#
# 115_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_115_chpn_op7_2.wav Done
# out_115_chpn_op7_2.wav Done
#
# 115_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_115_chp_op18.wav Done
# out_115_chp_op18.wav Done
#
# 115_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_115_chp_op31.wav Done
# out_115_chp_op31.wav Done
#
# 115_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_120_chpn-p13.wav Done
# out_120_chpn-p13.wav Done
#
# 120_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_120_chpn-p15.wav Done
# out_120_chpn-p15.wav Done
#
# 120_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_120_chpn-p17.wav Done
# out_120_chpn-p17.wav Done
#
# 120_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op10_e12.wav Done
# out_120_chpn_op10_e12.wav Done
#
# 120_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op23.wav Done
# out_120_chpn_op23.wav Done
#
# 120_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op25_e11.wav Done
# out_120_chpn_op25_e11.wav Done
#
# 120_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op25_e12.wav Done
# out_120_chpn_op25_e12.wav Done
#
# 120_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op27_1.wav Done
# out_120_chpn_op27_1.wav Done
#
# 120_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op27_2.wav Done
# out_120_chpn_op27_2.wav Done
#
# 120_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op33_2.wav Done
# out_120_chpn_op33_2.wav Done
#
# 120_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op33_4.wav Done
# out_120_chpn_op33_4.wav Done
#
# 120_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op35_1.wav Done
# out_120_chpn_op35_1.wav Done
#
# 120_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op35_2.wav Done
# out_120_chpn_op35_2.wav Done
#
# 120_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op35_3.wav Done
# out_120_chpn_op35_3.wav Done
#
# 120_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op53.wav Done
# out_120_chpn_op53.wav Done
#
# 120_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op66.wav Done
# out_120_chpn_op66.wav Done
#
# 120_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op7_1.wav Done
# out_120_chpn_op7_1.wav Done
#
# 120_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_120_chpn_op7_2.wav Done
# out_120_chpn_op7_2.wav Done
#
# 120_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_120_chp_op18.wav Done
# out_120_chp_op18.wav Done
#
# 120_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_120_chp_op31.wav Done
# out_120_chp_op31.wav Done
#
# 120_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_125_chpn-p13.wav Done
# out_125_chpn-p13.wav Done
#
# 125_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_125_chpn-p15.wav Done
# out_125_chpn-p15.wav Done
#
# 125_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_125_chpn-p17.wav Done
# out_125_chpn-p17.wav Done
#
# 125_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op23.wav Done
# out_125_chpn_op23.wav Done
#
# 125_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op25_e11.wav Done
# out_125_chpn_op25_e11.wav Done
#
# 125_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op27_1.wav Done
# out_125_chpn_op27_1.wav Done
#
# 125_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op27_2.wav Done
# out_125_chpn_op27_2.wav Done
#
# 125_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op33_2.wav Done
# out_125_chpn_op33_2.wav Done
#
# 125_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op33_4.wav Done
# out_125_chpn_op33_4.wav Done
#
# 125_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op35_1.wav Done
# out_125_chpn_op35_1.wav Done
#
# 125_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op35_2.wav Done
# out_125_chpn_op35_2.wav Done
#
# 125_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op35_3.wav Done
# out_125_chpn_op35_3.wav Done
#
# 125_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op53.wav Done
# out_125_chpn_op53.wav Done
#
# 125_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op66.wav Done
# out_125_chpn_op66.wav Done
#
# 125_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_125_chpn_op7_2.wav Done
# out_125_chpn_op7_2.wav Done
#
# 125_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_125_chp_op18.wav Done
# out_125_chp_op18.wav Done
#
# 125_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_125_chp_op31.wav Done
# out_125_chp_op31.wav Done
#
# 125_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_130_chpn-p13.wav Done
# out_130_chpn-p13.wav Done
#
# 130_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_130_chpn-p15.wav Done
# out_130_chpn-p15.wav Done
#
# 130_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_130_chpn-p17.wav Done
# out_130_chpn-p17.wav Done
#
# 130_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op23.wav Done
# out_130_chpn_op23.wav Done
#
# 130_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op25_e11.wav Done
# out_130_chpn_op25_e11.wav Done
#
# 130_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op27_1.wav Done
# out_130_chpn_op27_1.wav Done
#
# 130_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op27_2.wav Done
# out_130_chpn_op27_2.wav Done
#
# 130_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op33_4.wav Done
# out_130_chpn_op33_4.wav Done
#
# 130_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op35_1.wav Done
# out_130_chpn_op35_1.wav Done
#
# 130_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op35_2.wav Done
# out_130_chpn_op35_2.wav Done
#
# 130_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op35_3.wav Done
# out_130_chpn_op35_3.wav Done
#
# 130_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op53.wav Done
# out_130_chpn_op53.wav Done
#
# 130_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op66.wav Done
# out_130_chpn_op66.wav Done
#
# 130_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_130_chpn_op7_2.wav Done
# out_130_chpn_op7_2.wav Done
#
# 130_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_130_chp_op18.wav Done
# out_130_chp_op18.wav Done
#
# 130_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_130_chp_op31.wav Done
# out_130_chp_op31.wav Done
#
# 130_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_135_chpn-p13.wav Done
# out_135_chpn-p13.wav Done
#
# 135_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_135_chpn-p15.wav Done
# out_135_chpn-p15.wav Done
#
# 135_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_135_chpn-p17.wav Done
# out_135_chpn-p17.wav Done
#
# 135_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op23.wav Done
# out_135_chpn_op23.wav Done
#
# 135_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op25_e11.wav Done
# out_135_chpn_op25_e11.wav Done
#
# 135_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op27_1.wav Done
# out_135_chpn_op27_1.wav Done
#
# 135_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op27_2.wav Done
# out_135_chpn_op27_2.wav Done
#
# 135_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op33_4.wav Done
# out_135_chpn_op33_4.wav Done
#
# 135_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op35_1.wav Done
# out_135_chpn_op35_1.wav Done
#
# 135_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op35_2.wav Done
# out_135_chpn_op35_2.wav Done
#
# 135_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op35_3.wav Done
# out_135_chpn_op35_3.wav Done
#
# 135_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op53.wav Done
# out_135_chpn_op53.wav Done
#
# 135_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op66.wav Done
# out_135_chpn_op66.wav Done
#
# 135_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_135_chpn_op7_2.wav Done
# out_135_chpn_op7_2.wav Done
#
# 135_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_135_chp_op18.wav Done
# out_135_chp_op18.wav Done
#
# 135_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_135_chp_op31.wav Done
# out_135_chp_op31.wav Done
#
# 135_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_140_chpn-p15.wav Done
# out_140_chpn-p15.wav Done
#
# 140_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_140_chpn-p17.wav Done
# out_140_chpn-p17.wav Done
#
# 140_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op23.wav Done
# out_140_chpn_op23.wav Done
#
# 140_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op25_e11.wav Done
# out_140_chpn_op25_e11.wav Done
#
# 140_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op27_1.wav Done
# out_140_chpn_op27_1.wav Done
#
# 140_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op27_2.wav Done
# out_140_chpn_op27_2.wav Done
#
# 140_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op33_4.wav Done
# out_140_chpn_op33_4.wav Done
#
# 140_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op35_1.wav Done
# out_140_chpn_op35_1.wav Done
#
# 140_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op35_2.wav Done
# out_140_chpn_op35_2.wav Done
#
# 140_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op35_3.wav Done
# out_140_chpn_op35_3.wav Done
#
# 140_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op53.wav Done
# out_140_chpn_op53.wav Done
#
# 140_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op66.wav Done
# out_140_chpn_op66.wav Done
#
# 140_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_140_chpn_op7_2.wav Done
# out_140_chpn_op7_2.wav Done
#
# 140_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_140_chp_op18.wav Done
# out_140_chp_op18.wav Done
#
# 140_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_140_chp_op31.wav Done
# out_140_chp_op31.wav Done
#
# 140_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_145_chpn-p15.wav Done
# out_145_chpn-p15.wav Done
#
# 145_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op23.wav Done
# out_145_chpn_op23.wav Done
#
# 145_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op25_e11.wav Done
# out_145_chpn_op25_e11.wav Done
#
# 145_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op27_1.wav Done
# out_145_chpn_op27_1.wav Done
#
# 145_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op27_2.wav Done
# out_145_chpn_op27_2.wav Done
#
# 145_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op33_4.wav Done
# out_145_chpn_op33_4.wav Done
#
# 145_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op35_1.wav Done
# out_145_chpn_op35_1.wav Done
#
# 145_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op35_2.wav Done
# out_145_chpn_op35_2.wav Done
#
# 145_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op35_3.wav Done
# out_145_chpn_op35_3.wav Done
#
# 145_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op53.wav Done
# out_145_chpn_op53.wav Done
#
# 145_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op66.wav Done
# out_145_chpn_op66.wav Done
#
# 145_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_145_chpn_op7_2.wav Done
# out_145_chpn_op7_2.wav Done
#
# 145_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_145_chp_op18.wav Done
# out_145_chp_op18.wav Done
#
# 145_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_145_chp_op31.wav Done
# out_145_chp_op31.wav Done
#
# 145_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_150_chpn-p15.wav Done
# out_150_chpn-p15.wav Done
#
# 150_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op23.wav Done
# out_150_chpn_op23.wav Done
#
# 150_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op25_e11.wav Done
# out_150_chpn_op25_e11.wav Done
#
# 150_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op27_1.wav Done
# out_150_chpn_op27_1.wav Done
#
# 150_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op27_2.wav Done
# out_150_chpn_op27_2.wav Done
#
# 150_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op33_4.wav Done
# out_150_chpn_op33_4.wav Done
#
# 150_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op35_1.wav Done
# out_150_chpn_op35_1.wav Done
#
# 150_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op35_2.wav Done
# out_150_chpn_op35_2.wav Done
#
# 150_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op35_3.wav Done
# out_150_chpn_op35_3.wav Done
#
# 150_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op53.wav Done
# out_150_chpn_op53.wav Done
#
# 150_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_150_chpn_op66.wav Done
# out_150_chpn_op66.wav Done
#
# 150_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_150_chp_op18.wav Done
# out_150_chp_op18.wav Done
#
# 150_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_150_chp_op31.wav Done
# out_150_chp_op31.wav Done
#
# 150_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_155_chpn-p15.wav Done
# out_155_chpn-p15.wav Done
#
# 155_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op23.wav Done
# out_155_chpn_op23.wav Done
#
# 155_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op25_e11.wav Done
# out_155_chpn_op25_e11.wav Done
#
# 155_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op27_1.wav Done
# out_155_chpn_op27_1.wav Done
#
# 155_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op27_2.wav Done
# out_155_chpn_op27_2.wav Done
#
# 155_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op33_4.wav Done
# out_155_chpn_op33_4.wav Done
#
# 155_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op35_1.wav Done
# out_155_chpn_op35_1.wav Done
#
# 155_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op35_2.wav Done
# out_155_chpn_op35_2.wav Done
#
# 155_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op35_3.wav Done
# out_155_chpn_op35_3.wav Done
#
# 155_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op53.wav Done
# out_155_chpn_op53.wav Done
#
# 155_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_155_chpn_op66.wav Done
# out_155_chpn_op66.wav Done
#
# 155_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_155_chp_op18.wav Done
# out_155_chp_op18.wav Done
#
# 155_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_155_chp_op31.wav Done
# out_155_chp_op31.wav Done
#
# 155_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p1.wav Done
# out_15_chpn-p1.wav Done
#
# 15_chpn-p1.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p11.wav Done
# out_15_chpn-p11.wav Done
#
# 15_chpn-p11.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p12.wav Done
# out_15_chpn-p12.wav Done
#
# 15_chpn-p12.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p13.wav Done
# out_15_chpn-p13.wav Done
#
# 15_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p15.wav Done
# out_15_chpn-p15.wav Done
#
# 15_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p16.wav Done
# out_15_chpn-p16.wav Done
#
# 15_chpn-p16.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p17.wav Done
# out_15_chpn-p17.wav Done
#
# 15_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p18.wav Done
# out_15_chpn-p18.wav Done
#
# 15_chpn-p18.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p19.wav Done
# out_15_chpn-p19.wav Done
#
# 15_chpn-p19.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p2.wav Done
# out_15_chpn-p2.wav Done
#
# 15_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p20.wav Done
# out_15_chpn-p20.wav Done
#
# 15_chpn-p20.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p21.wav Done
# out_15_chpn-p21.wav Done
#
# 15_chpn-p21.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p22.wav Done
# out_15_chpn-p22.wav Done
#
# 15_chpn-p22.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p23.wav Done
# out_15_chpn-p23.wav Done
#
# 15_chpn-p23.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p24.wav Done
# out_15_chpn-p24.wav Done
#
# 15_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p3.wav Done
# out_15_chpn-p3.wav Done
#
# 15_chpn-p3.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p4.wav Done
# out_15_chpn-p4.wav Done
#
# 15_chpn-p4.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p5.wav Done
# out_15_chpn-p5.wav Done
#
# 15_chpn-p5.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p6.wav Done
# out_15_chpn-p6.wav Done
#
# 15_chpn-p6.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p7.wav Done
# out_15_chpn-p7.wav Done
#
# 15_chpn-p7.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p8.wav Done
# out_15_chpn-p8.wav Done
#
# 15_chpn-p8.wav file splitted into 7.5 sec files
#
#
# in_15_chpn-p9.wav Done
# out_15_chpn-p9.wav Done
#
# 15_chpn-p9.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op10_e01.wav Done
# out_15_chpn_op10_e01.wav Done
#
# 15_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op10_e05.wav Done
# out_15_chpn_op10_e05.wav Done
#
# 15_chpn_op10_e05.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op10_e12.wav Done
# out_15_chpn_op10_e12.wav Done
#
# 15_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op23.wav Done
# out_15_chpn_op23.wav Done
#
# 15_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op25_e1.wav Done
# out_15_chpn_op25_e1.wav Done
#
# 15_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op25_e11.wav Done
# out_15_chpn_op25_e11.wav Done
#
# 15_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op25_e12.wav Done
# out_15_chpn_op25_e12.wav Done
#
# 15_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op25_e2.wav Done
# out_15_chpn_op25_e2.wav Done
#
# 15_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op25_e3.wav Done
# out_15_chpn_op25_e3.wav Done
#
# 15_chpn_op25_e3.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op25_e4.wav Done
# out_15_chpn_op25_e4.wav Done
#
# 15_chpn_op25_e4.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op27_1.wav Done
# out_15_chpn_op27_1.wav Done
#
# 15_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op27_2.wav Done
# out_15_chpn_op27_2.wav Done
#
# 15_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op33_2.wav Done
# out_15_chpn_op33_2.wav Done
#
# 15_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op33_4.wav Done
# out_15_chpn_op33_4.wav Done
#
# 15_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op35_1.wav Done
# out_15_chpn_op35_1.wav Done
#
# 15_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op35_2.wav Done
# out_15_chpn_op35_2.wav Done
#
# 15_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op35_3.wav Done
# out_15_chpn_op35_3.wav Done
#
# 15_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op35_4.wav Done
# out_15_chpn_op35_4.wav Done
#
# 15_chpn_op35_4.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op53.wav Done
# out_15_chpn_op53.wav Done
#
# 15_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op66.wav Done
# out_15_chpn_op66.wav Done
#
# 15_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op7_1.wav Done
# out_15_chpn_op7_1.wav Done
#
# 15_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_15_chpn_op7_2.wav Done
# out_15_chpn_op7_2.wav Done
#
# 15_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_15_chp_op18.wav Done
# out_15_chp_op18.wav Done
#
# 15_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_15_chp_op31.wav Done
# out_15_chp_op31.wav Done
#
# 15_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_160_chpn-p15.wav Done
# out_160_chpn-p15.wav Done
#
# 160_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op23.wav Done
# out_160_chpn_op23.wav Done
#
# 160_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op25_e11.wav Done
# out_160_chpn_op25_e11.wav Done
#
# 160_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op27_1.wav Done
# out_160_chpn_op27_1.wav Done
#
# 160_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op27_2.wav Done
# out_160_chpn_op27_2.wav Done
#
# 160_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op33_4.wav Done
# out_160_chpn_op33_4.wav Done
#
# 160_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op35_1.wav Done
# out_160_chpn_op35_1.wav Done
#
# 160_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op35_2.wav Done
# out_160_chpn_op35_2.wav Done
#
# 160_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op35_3.wav Done
# out_160_chpn_op35_3.wav Done
#
# 160_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op53.wav Done
# out_160_chpn_op53.wav Done
#
# 160_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_160_chpn_op66.wav Done
# out_160_chpn_op66.wav Done
#
# 160_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_160_chp_op18.wav Done
# out_160_chp_op18.wav Done
#
# 160_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_160_chp_op31.wav Done
# out_160_chp_op31.wav Done
#
# 160_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_165_chpn-p15.wav Done
# out_165_chpn-p15.wav Done
#
# 165_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op23.wav Done
# out_165_chpn_op23.wav Done
#
# 165_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op25_e11.wav Done
# out_165_chpn_op25_e11.wav Done
#
# 165_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op27_1.wav Done
# out_165_chpn_op27_1.wav Done
#
# 165_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op27_2.wav Done
# out_165_chpn_op27_2.wav Done
#
# 165_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op33_4.wav Done
# out_165_chpn_op33_4.wav Done
#
# 165_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op35_1.wav Done
# out_165_chpn_op35_1.wav Done
#
# 165_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op35_2.wav Done
# out_165_chpn_op35_2.wav Done
#
# 165_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op35_3.wav Done
# out_165_chpn_op35_3.wav Done
#
# 165_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op53.wav Done
# out_165_chpn_op53.wav Done
#
# 165_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_165_chpn_op66.wav Done
# out_165_chpn_op66.wav Done
#
# 165_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_165_chp_op18.wav Done
# out_165_chp_op18.wav Done
#
# 165_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_165_chp_op31.wav Done
# out_165_chp_op31.wav Done
#
# 165_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_170_chpn-p15.wav Done
# out_170_chpn-p15.wav Done
#
# 170_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op23.wav Done
# out_170_chpn_op23.wav Done
#
# 170_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op25_e11.wav Done
# out_170_chpn_op25_e11.wav Done
#
# 170_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op27_1.wav Done
# out_170_chpn_op27_1.wav Done
#
# 170_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op27_2.wav Done
# out_170_chpn_op27_2.wav Done
#
# 170_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op33_4.wav Done
# out_170_chpn_op33_4.wav Done
#
# 170_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op35_1.wav Done
# out_170_chpn_op35_1.wav Done
#
# 170_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op35_2.wav Done
# out_170_chpn_op35_2.wav Done
#
# 170_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op35_3.wav Done
# out_170_chpn_op35_3.wav Done
#
# 170_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op53.wav Done
# out_170_chpn_op53.wav Done
#
# 170_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_170_chpn_op66.wav Done
# out_170_chpn_op66.wav Done
#
# 170_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_170_chp_op18.wav Done
# out_170_chp_op18.wav Done
#
# 170_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_170_chp_op31.wav Done
# out_170_chp_op31.wav Done
#
# 170_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_175_chpn-p15.wav Done
# out_175_chpn-p15.wav Done
#
# 175_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op23.wav Done
# out_175_chpn_op23.wav Done
#
# 175_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op27_1.wav Done
# out_175_chpn_op27_1.wav Done
#
# 175_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op27_2.wav Done
# out_175_chpn_op27_2.wav Done
#
# 175_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op33_4.wav Done
# out_175_chpn_op33_4.wav Done
#
# 175_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op35_1.wav Done
# out_175_chpn_op35_1.wav Done
#
# 175_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op35_2.wav Done
# out_175_chpn_op35_2.wav Done
#
# 175_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op35_3.wav Done
# out_175_chpn_op35_3.wav Done
#
# 175_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op53.wav Done
# out_175_chpn_op53.wav Done
#
# 175_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_175_chpn_op66.wav Done
# out_175_chpn_op66.wav Done
#
# 175_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_175_chp_op18.wav Done
# out_175_chp_op18.wav Done
#
# 175_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_175_chp_op31.wav Done
# out_175_chp_op31.wav Done
#
# 175_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_180_chpn-p15.wav Done
# out_180_chpn-p15.wav Done
#
# 180_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op23.wav Done
# out_180_chpn_op23.wav Done
#
# 180_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op27_1.wav Done
# out_180_chpn_op27_1.wav Done
#
# 180_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op27_2.wav Done
# out_180_chpn_op27_2.wav Done
#
# 180_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op33_4.wav Done
# out_180_chpn_op33_4.wav Done
#
# 180_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op35_1.wav Done
# out_180_chpn_op35_1.wav Done
#
# 180_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op35_2.wav Done
# out_180_chpn_op35_2.wav Done
#
# 180_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op35_3.wav Done
# out_180_chpn_op35_3.wav Done
#
# 180_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op53.wav Done
# out_180_chpn_op53.wav Done
#
# 180_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_180_chpn_op66.wav Done
# out_180_chpn_op66.wav Done
#
# 180_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_180_chp_op18.wav Done
# out_180_chp_op18.wav Done
#
# 180_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_180_chp_op31.wav Done
# out_180_chp_op31.wav Done
#
# 180_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_185_chpn-p15.wav Done
# out_185_chpn-p15.wav Done
#
# 185_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op23.wav Done
# out_185_chpn_op23.wav Done
#
# 185_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op27_1.wav Done
# out_185_chpn_op27_1.wav Done
#
# 185_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op27_2.wav Done
# out_185_chpn_op27_2.wav Done
#
# 185_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op33_4.wav Done
# out_185_chpn_op33_4.wav Done
#
# 185_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op35_1.wav Done
# out_185_chpn_op35_1.wav Done
#
# 185_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op35_2.wav Done
# out_185_chpn_op35_2.wav Done
#
# 185_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op35_3.wav Done
# out_185_chpn_op35_3.wav Done
#
# 185_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op53.wav Done
# out_185_chpn_op53.wav Done
#
# 185_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_185_chpn_op66.wav Done
# out_185_chpn_op66.wav Done
#
# 185_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_185_chp_op18.wav Done
# out_185_chp_op18.wav Done
#
# 185_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_185_chp_op31.wav Done
# out_185_chp_op31.wav Done
#
# 185_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_190_chpn-p15.wav Done
# out_190_chpn-p15.wav Done
#
# 190_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op23.wav Done
# out_190_chpn_op23.wav Done
#
# 190_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op27_1.wav Done
# out_190_chpn_op27_1.wav Done
#
# 190_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op27_2.wav Done
# out_190_chpn_op27_2.wav Done
#
# 190_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op33_4.wav Done
# out_190_chpn_op33_4.wav Done
#
# 190_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op35_1.wav Done
# out_190_chpn_op35_1.wav Done
#
# 190_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op35_2.wav Done
# out_190_chpn_op35_2.wav Done
#
# 190_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op35_3.wav Done
# out_190_chpn_op35_3.wav Done
#
# 190_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op53.wav Done
# out_190_chpn_op53.wav Done
#
# 190_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_190_chpn_op66.wav Done
# out_190_chpn_op66.wav Done
#
# 190_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_190_chp_op18.wav Done
# ...
#
#
# in_70_chpn_op35_1.wav Done
# out_70_chpn_op35_1.wav Done
#
# 70_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_70_chpn_op35_2.wav Done
# out_70_chpn_op35_2.wav Done
#
# 70_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_70_chpn_op35_3.wav Done
# out_70_chpn_op35_3.wav Done
#
# 70_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_70_chpn_op53.wav Done
# out_70_chpn_op53.wav Done
#
# 70_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_70_chpn_op66.wav Done
# out_70_chpn_op66.wav Done
#
# 70_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_70_chpn_op7_1.wav Done
# out_70_chpn_op7_1.wav Done
#
# 70_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_70_chpn_op7_2.wav Done
# out_70_chpn_op7_2.wav Done
#
# 70_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_70_chp_op18.wav Done
# out_70_chp_op18.wav Done
#
# 70_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_70_chp_op31.wav Done
# out_70_chp_op31.wav Done
#
# 70_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p13.wav Done
# out_75_chpn-p13.wav Done
#
# 75_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p15.wav Done
# out_75_chpn-p15.wav Done
#
# 75_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p17.wav Done
# out_75_chpn-p17.wav Done
#
# 75_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p2.wav Done
# out_75_chpn-p2.wav Done
#
# 75_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p21.wav Done
# out_75_chpn-p21.wav Done
#
# 75_chpn-p21.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p24.wav Done
# out_75_chpn-p24.wav Done
#
# 75_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p4.wav Done
# out_75_chpn-p4.wav Done
#
# 75_chpn-p4.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p6.wav Done
# out_75_chpn-p6.wav Done
#
# 75_chpn-p6.wav file splitted into 7.5 sec files
#
#
# in_75_chpn-p8.wav Done
# out_75_chpn-p8.wav Done
#
# 75_chpn-p8.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op10_e01.wav Done
# out_75_chpn_op10_e01.wav Done
#
# 75_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op10_e05.wav Done
# out_75_chpn_op10_e05.wav Done
#
# 75_chpn_op10_e05.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op10_e12.wav Done
# out_75_chpn_op10_e12.wav Done
#
# 75_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op23.wav Done
# out_75_chpn_op23.wav Done
#
# 75_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op25_e1.wav Done
# out_75_chpn_op25_e1.wav Done
#
# 75_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op25_e11.wav Done
# out_75_chpn_op25_e11.wav Done
#
# 75_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op25_e12.wav Done
# out_75_chpn_op25_e12.wav Done
#
# 75_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op25_e2.wav Done
# out_75_chpn_op25_e2.wav Done
#
# 75_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op25_e3.wav Done
# out_75_chpn_op25_e3.wav Done
#
# 75_chpn_op25_e3.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op27_1.wav Done
# out_75_chpn_op27_1.wav Done
#
# 75_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op27_2.wav Done
# out_75_chpn_op27_2.wav Done
#
# 75_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op33_2.wav Done
# out_75_chpn_op33_2.wav Done
#
# 75_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op33_4.wav Done
# out_75_chpn_op33_4.wav Done
#
# 75_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op35_1.wav Done
# out_75_chpn_op35_1.wav Done
#
# 75_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op35_2.wav Done
# out_75_chpn_op35_2.wav Done
#
# 75_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op35_3.wav Done
# out_75_chpn_op35_3.wav Done
#
# 75_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op53.wav Done
# out_75_chpn_op53.wav Done
#
# 75_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op66.wav Done
# out_75_chpn_op66.wav Done
#
# 75_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op7_1.wav Done
# out_75_chpn_op7_1.wav Done
#
# 75_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_75_chpn_op7_2.wav Done
# out_75_chpn_op7_2.wav Done
#
# 75_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_75_chp_op18.wav Done
# out_75_chp_op18.wav Done
#
# 75_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_75_chp_op31.wav Done
# out_75_chp_op31.wav Done
#
# 75_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p13.wav Done
# out_80_chpn-p13.wav Done
#
# 80_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p15.wav Done
# out_80_chpn-p15.wav Done
#
# 80_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p17.wav Done
# out_80_chpn-p17.wav Done
#
# 80_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p2.wav Done
# out_80_chpn-p2.wav Done
#
# 80_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p21.wav Done
# out_80_chpn-p21.wav Done
#
# 80_chpn-p21.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p24.wav Done
# out_80_chpn-p24.wav Done
#
# 80_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p4.wav Done
# out_80_chpn-p4.wav Done
#
# 80_chpn-p4.wav file splitted into 7.5 sec files
#
#
# in_80_chpn-p6.wav Done
# out_80_chpn-p6.wav Done
#
# 80_chpn-p6.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op10_e01.wav Done
# out_80_chpn_op10_e01.wav Done
#
# 80_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op10_e12.wav Done
# out_80_chpn_op10_e12.wav Done
#
# 80_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op23.wav Done
# out_80_chpn_op23.wav Done
#
# 80_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op25_e1.wav Done
# out_80_chpn_op25_e1.wav Done
#
# 80_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op25_e11.wav Done
# out_80_chpn_op25_e11.wav Done
#
# 80_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op25_e12.wav Done
# out_80_chpn_op25_e12.wav Done
#
# 80_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op25_e2.wav Done
# out_80_chpn_op25_e2.wav Done
#
# 80_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op25_e3.wav Done
# out_80_chpn_op25_e3.wav Done
#
# 80_chpn_op25_e3.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op27_1.wav Done
# out_80_chpn_op27_1.wav Done
#
# 80_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op27_2.wav Done
# out_80_chpn_op27_2.wav Done
#
# 80_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op33_2.wav Done
# out_80_chpn_op33_2.wav Done
#
# 80_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op33_4.wav Done
# out_80_chpn_op33_4.wav Done
#
# 80_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op35_1.wav Done
# out_80_chpn_op35_1.wav Done
#
# 80_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op35_2.wav Done
# out_80_chpn_op35_2.wav Done
#
# 80_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op35_3.wav Done
# out_80_chpn_op35_3.wav Done
#
# 80_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op53.wav Done
# out_80_chpn_op53.wav Done
#
# 80_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op66.wav Done
# out_80_chpn_op66.wav Done
#
# 80_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op7_1.wav Done
# out_80_chpn_op7_1.wav Done
#
# 80_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_80_chpn_op7_2.wav Done
# out_80_chpn_op7_2.wav Done
#
# 80_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_80_chp_op18.wav Done
# out_80_chp_op18.wav Done
#
# 80_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_80_chp_op31.wav Done
# out_80_chp_op31.wav Done
#
# 80_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_85_chpn-p13.wav Done
# out_85_chpn-p13.wav Done
#
# 85_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_85_chpn-p15.wav Done
# out_85_chpn-p15.wav Done
#
# 85_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_85_chpn-p17.wav Done
# out_85_chpn-p17.wav Done
#
# 85_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_85_chpn-p2.wav Done
# out_85_chpn-p2.wav Done
#
# 85_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_85_chpn-p21.wav Done
# out_85_chpn-p21.wav Done
#
# 85_chpn-p21.wav file splitted into 7.5 sec files
#
#
# in_85_chpn-p24.wav Done
# out_85_chpn-p24.wav Done
#
# 85_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_85_chpn-p4.wav Done
# out_85_chpn-p4.wav Done
#
# 85_chpn-p4.wav file splitted into 7.5 sec files
# in_85_chpn_op10_e01.wav Done
# out_85_chpn_op10_e01.wav Done
#
# 85_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op10_e12.wav Done
# out_85_chpn_op10_e12.wav Done
#
# 85_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op23.wav Done
# out_85_chpn_op23.wav Done
#
# 85_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op25_e1.wav Done
# out_85_chpn_op25_e1.wav Done
#
# 85_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op25_e11.wav Done
# out_85_chpn_op25_e11.wav Done
#
# 85_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op25_e12.wav Done
# out_85_chpn_op25_e12.wav Done
#
# 85_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op25_e2.wav Done
# out_85_chpn_op25_e2.wav Done
#
# 85_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op25_e3.wav Done
# out_85_chpn_op25_e3.wav Done
#
# 85_chpn_op25_e3.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op27_1.wav Done
# out_85_chpn_op27_1.wav Done
#
# 85_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op27_2.wav Done
# out_85_chpn_op27_2.wav Done
#
# 85_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op33_2.wav Done
# out_85_chpn_op33_2.wav Done
#
# 85_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op33_4.wav Done
# out_85_chpn_op33_4.wav Done
#
# 85_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op35_1.wav Done
# out_85_chpn_op35_1.wav Done
#
# 85_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op35_2.wav Done
# out_85_chpn_op35_2.wav Done
#
# 85_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op35_3.wav Done
# out_85_chpn_op35_3.wav Done
#
# 85_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op53.wav Done
# out_85_chpn_op53.wav Done
#
# 85_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op66.wav Done
# out_85_chpn_op66.wav Done
#
# 85_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op7_1.wav Done
# out_85_chpn_op7_1.wav Done
#
# 85_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_85_chpn_op7_2.wav Done
# out_85_chpn_op7_2.wav Done
#
# 85_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_85_chp_op18.wav Done
# out_85_chp_op18.wav Done
#
# 85_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_85_chp_op31.wav Done
# out_85_chp_op31.wav Done
#
# 85_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_90_chpn-p13.wav Done
# out_90_chpn-p13.wav Done
#
# 90_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_90_chpn-p15.wav Done
# out_90_chpn-p15.wav Done
#
# 90_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_90_chpn-p17.wav Done
# out_90_chpn-p17.wav Done
#
# 90_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_90_chpn-p2.wav Done
# out_90_chpn-p2.wav Done
#
# 90_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_90_chpn-p21.wav Done
# out_90_chpn-p21.wav Done
#
# 90_chpn-p21.wav file splitted into 7.5 sec files
#
#
# in_90_chpn-p24.wav Done
# out_90_chpn-p24.wav Done
#
# 90_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op10_e01.wav Done
# out_90_chpn_op10_e01.wav Done
#
# 90_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op10_e12.wav Done
# out_90_chpn_op10_e12.wav Done
#
# 90_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op23.wav Done
# out_90_chpn_op23.wav Done
#
# 90_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op25_e1.wav Done
# out_90_chpn_op25_e1.wav Done
#
# 90_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op25_e11.wav Done
# out_90_chpn_op25_e11.wav Done
#
# 90_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op25_e12.wav Done
# out_90_chpn_op25_e12.wav Done
#
# 90_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op25_e2.wav Done
# out_90_chpn_op25_e2.wav Done
#
# 90_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op27_1.wav Done
# out_90_chpn_op27_1.wav Done
#
# 90_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op27_2.wav Done
# out_90_chpn_op27_2.wav Done
#
# 90_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op33_2.wav Done
# out_90_chpn_op33_2.wav Done
#
# 90_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op33_4.wav Done
# out_90_chpn_op33_4.wav Done
#
# 90_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op35_1.wav Done
# out_90_chpn_op35_1.wav Done
#
# 90_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op35_2.wav Done
# out_90_chpn_op35_2.wav Done
#
# 90_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op35_3.wav Done
# out_90_chpn_op35_3.wav Done
#
# 90_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op53.wav Done
# out_90_chpn_op53.wav Done
#
# 90_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op66.wav Done
# out_90_chpn_op66.wav Done
#
# 90_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op7_1.wav Done
# out_90_chpn_op7_1.wav Done
#
# 90_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_90_chpn_op7_2.wav Done
# out_90_chpn_op7_2.wav Done
#
# 90_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_90_chp_op18.wav Done
# out_90_chp_op18.wav Done
#
# 90_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_90_chp_op31.wav Done
# out_90_chp_op31.wav Done
#
# 90_chp_op31.wav file splitted into 7.5 sec files
#
#
# in_95_chpn-p13.wav Done
# out_95_chpn-p13.wav Done
#
# 95_chpn-p13.wav file splitted into 7.5 sec files
#
#
# in_95_chpn-p15.wav Done
# out_95_chpn-p15.wav Done
#
# 95_chpn-p15.wav file splitted into 7.5 sec files
#
#
# in_95_chpn-p17.wav Done
# out_95_chpn-p17.wav Done
#
# 95_chpn-p17.wav file splitted into 7.5 sec files
#
#
# in_95_chpn-p2.wav Done
# out_95_chpn-p2.wav Done
#
# 95_chpn-p2.wav file splitted into 7.5 sec files
#
#
# in_95_chpn-p24.wav Done
# out_95_chpn-p24.wav Done
#
# 95_chpn-p24.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op10_e01.wav Done
# out_95_chpn_op10_e01.wav Done
#
# 95_chpn_op10_e01.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op10_e12.wav Done
# out_95_chpn_op10_e12.wav Done
#
# 95_chpn_op10_e12.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op23.wav Done
# out_95_chpn_op23.wav Done
#
# 95_chpn_op23.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op25_e1.wav Done
# out_95_chpn_op25_e1.wav Done
#
# 95_chpn_op25_e1.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op25_e11.wav Done
# out_95_chpn_op25_e11.wav Done
#
# 95_chpn_op25_e11.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op25_e12.wav Done
# out_95_chpn_op25_e12.wav Done
#
# 95_chpn_op25_e12.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op25_e2.wav Done
# out_95_chpn_op25_e2.wav Done
#
# 95_chpn_op25_e2.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op27_1.wav Done
# out_95_chpn_op27_1.wav Done
#
# 95_chpn_op27_1.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op27_2.wav Done
# out_95_chpn_op27_2.wav Done
#
# 95_chpn_op27_2.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op33_2.wav Done
# out_95_chpn_op33_2.wav Done
#
# 95_chpn_op33_2.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op33_4.wav Done
# out_95_chpn_op33_4.wav Done
#
# 95_chpn_op33_4.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op35_1.wav Done
# out_95_chpn_op35_1.wav Done
#
# 95_chpn_op35_1.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op35_2.wav Done
# out_95_chpn_op35_2.wav Done
#
# 95_chpn_op35_2.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op35_3.wav Done
# out_95_chpn_op35_3.wav Done
#
# 95_chpn_op35_3.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op53.wav Done
# out_95_chpn_op53.wav Done
#
# 95_chpn_op53.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op66.wav Done
# out_95_chpn_op66.wav Done
#
# 95_chpn_op66.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op7_1.wav Done
# out_95_chpn_op7_1.wav Done
#
# 95_chpn_op7_1.wav file splitted into 7.5 sec files
#
#
# in_95_chpn_op7_2.wav Done
# out_95_chpn_op7_2.wav Done
#
# 95_chpn_op7_2.wav file splitted into 7.5 sec files
#
#
# in_95_chp_op18.wav Done
# out_95_chp_op18.wav Done
#
# 95_chp_op18.wav file splitted into 7.5 sec files
#
#
# in_95_chp_op31.wav Done
# out_95_chp_op31.wav Done
#
# 95_chp_op31.wav file splitted into 7.5 sec files

# %% [markdown]
# **Spectogram conversion of the wav files and save as 'chopin_spectograms'**

# %%
from matplotlib import pyplot as plt

import scipy
from scipy.io.wavfile import write

# %%
# working from local directory from this point

segmented_filepath = '/Users/SAMSUNG/Downloads/dnn_data/train_input/'
audio_clips = os.listdir(segmented_filepath)

# file download check after cutting off different sized arrays
len(audio_clips)

# %%
segmented_filepath = '/Users/SAMSUNG/Downloads/dnn_data/test_input/'
audio_clips = os.listdir(segmented_filepath)

# file download check after cutting off different sized arrays
len(audio_clips)
# Out:
# 157

# %%
segmented_filepath = '/Users/SAMSUNG/Downloads/dnn_data/train_output/'
audio_clips = os.listdir(segmented_filepath)

# file download check after cutting off different sized arrays
len(audio_clips)
# Out:
# 1274

# %%
segmented_filepath = '/Users/SAMSUNG/Downloads/dnn_data/test_output/'
audio_clips = os.listdir(segmented_filepath)

# file download check after cutting off different sized arrays
len(audio_clips)
# Out:
# 157

# %%
audio_list = audio_clips

length = len(audio_clips)

# random spectogram array to begin with

random_num = random.randint(0, length)
y, sr = librosa.load(segmented_filepath+audio_list[random_num], sr=44100)

spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512)
spect = librosa.power_to_db(spect, ref=1.0)
x = np.expand_dims(spect, 0)


for i in range(len(audio_list)):

    # wav to specto array conversion

    y, sr = librosa.load(segmented_filepath+audio_list[i], sr=44100)

    spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512)
    spect = librosa.power_to_db(spect, ref=1.0)
    x_spect = np.expand_dims(spect, 0)
    
    x = np.append(x, x_spect, axis=0)
    print(audio_list[i] + ' converted to specto array, added to total numpy array \n')
    

print('spectogram downloads completed')
# Out:
# out_300_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_300_chpn_op33_4.wav converted to specto array, added to total numpy array
#
# out_300_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_300_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_300_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_300_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_300_chp_op31.wav converted to specto array, added to total numpy array
#
# out_305_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_305_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_305_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_305_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_305_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_305_chp_op31.wav converted to specto array, added to total numpy array
#
# out_310_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_310_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_310_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_310_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_310_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_310_chp_op31.wav converted to specto array, added to total numpy array
#
# out_315_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_315_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_315_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_315_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_315_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_315_chp_op31.wav converted to specto array, added to total numpy array
#
# out_320_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_320_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_320_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_320_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_320_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_320_chp_op31.wav converted to specto array, added to total numpy array
#
# out_325_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_325_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_325_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_325_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_325_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_325_chp_op31.wav converted to specto array, added to total numpy array
#
# out_330_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_330_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_330_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_330_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_330_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_330_chp_op31.wav converted to specto array, added to total numpy array
#
# out_335_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_335_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_335_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_335_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_335_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_335_chp_op31.wav converted to specto array, added to total numpy array
#
# out_340_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_340_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_340_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_340_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_340_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_340_chp_op31.wav converted to specto array, added to total numpy array
#
# out_345_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_345_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_345_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_345_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_345_chpn_op53.wav converted to specto array, added to total numpy array
#
# out_345_chp_op31.wav converted to specto array, added to total numpy array
#
# out_350_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_350_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_350_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_350_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_350_chp_op31.wav converted to specto array, added to total numpy array
#
# out_355_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_355_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_355_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_355_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_355_chp_op31.wav converted to specto array, added to total numpy array
#
# out_360_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_360_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_360_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_360_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_360_chp_op31.wav converted to specto array, added to total numpy array
#
# out_365_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_365_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_365_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_365_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_365_chp_op31.wav converted to specto array, added to total numpy array
#
# out_370_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_370_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_370_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_370_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_370_chp_op31.wav converted to specto array, added to total numpy array
#
# out_375_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_375_chpn_op35_1.wav converted to specto array, added to total numpy array
#
# out_375_chpn_op35_2.wav converted to specto array, added to total numpy array
#
# out_375_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_375_chp_op31.wav converted to specto array, added to total numpy array
#
# out_380_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_380_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_380_chp_op31.wav converted to specto array, added to total numpy array
#
# out_385_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_385_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_385_chp_op31.wav converted to specto array, added to total numpy array
#
# out_390_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_390_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_390_chp_op31.wav converted to specto array, added to total numpy array
#
# out_395_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_395_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_395_chp_op31.wav converted to specto array, added to total numpy array
#
# out_400_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_400_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_400_chp_op31.wav converted to specto array, added to total numpy array
#
# out_405_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_405_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_405_chp_op31.wav converted to specto array, added to total numpy array
# out_410_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_410_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_410_chp_op31.wav converted to specto array, added to total numpy array
#
# out_415_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_415_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_415_chp_op31.wav converted to specto array, added to total numpy array
#
# out_420_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_420_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_420_chp_op31.wav converted to specto array, added to total numpy array
#
# out_425_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_425_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_425_chp_op31.wav converted to specto array, added to total numpy array
#
# out_430_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_430_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_430_chp_op31.wav converted to specto array, added to total numpy array
#
# out_435_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_435_chpn_op35_3.wav converted to specto array, added to total numpy array
#
# out_435_chp_op31.wav converted to specto array, added to total numpy array
#
# out_440_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_440_chp_op31.wav converted to specto array, added to total numpy array
#
# out_445_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_445_chp_op31.wav converted to specto array, added to total numpy array
#
# out_450_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_450_chp_op31.wav converted to specto array, added to total numpy array
#
# out_455_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_455_chp_op31.wav converted to specto array, added to total numpy array
#
# out_460_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_460_chp_op31.wav converted to specto array, added to total numpy array
#
# out_465_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_465_chp_op31.wav converted to specto array, added to total numpy array
#
# out_470_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_470_chp_op31.wav converted to specto array, added to total numpy array
#
# out_475_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_475_chp_op31.wav converted to specto array, added to total numpy array
#
# out_480_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_480_chp_op31.wav converted to specto array, added to total numpy array
#
# out_485_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_485_chp_op31.wav converted to specto array, added to total numpy array
#
# out_490_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_490_chp_op31.wav converted to specto array, added to total numpy array
#
# out_495_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_495_chp_op31.wav converted to specto array, added to total numpy array
#
# out_500_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_500_chp_op31.wav converted to specto array, added to total numpy array
#
# out_505_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_510_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_515_chpn_op23.wav converted to specto array, added to total numpy array
#
# out_520_chpn_op23.wav converted to specto array, added to total numpy array
#
# spectogram downloads completed

# %%
x.shape
# Out:
# (158, 128, 646)

# %%
np.save("/Users/SAMSUNG/Downloads/dnn_data/x_train", x)

# %%
np.save("/Users/SAMSUNG/Downloads/dnn_data/x_test", x)

# %%
np.save("/Users/SAMSUNG/Downloads/dnn_data/y_train", x)

# %%
np.save("/Users/SAMSUNG/Downloads/dnn_data/y_test", x)
